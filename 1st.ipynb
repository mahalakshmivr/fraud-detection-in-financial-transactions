# %%
import pandas as pd
import numpy as np
data=pd.read_csv(r"C:\Users\Dell\Desktop\\book.csv")
print(data)
# Out:
#      step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1       1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2       1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3       1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4       1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
# ..    ...       ...       ...          ...            ...             ...
# 344     1   PAYMENT   5937.72  C1926180325        21779.0        15841.28
# 345     1   PAYMENT   9796.29  C1594039997       274658.0       264861.71
# 346     1   PAYMENT  13449.95  C1170788511        11080.0            0.00
# 347     1   PAYMENT   4749.60   C347091104         8038.0         3288.40
# 348     1   PAYMENT   6460.86  C1110195322        31009.0        24548.14
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
print(data.head())
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
print(data.tail())
# Out:
#      step     type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 344     1  PAYMENT   5937.72  C1926180325        21779.0        15841.28
# 345     1  PAYMENT   9796.29  C1594039997       274658.0       264861.71
# 346     1  PAYMENT  13449.95  C1170788511        11080.0            0.00
# 347     1  PAYMENT   4749.60   C347091104         8038.0         3288.40
# 348     1  PAYMENT   6460.86  C1110195322        31009.0        24548.14
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 344   M733461760             0.0             0.0        0               0
# 345  M1323531427             0.0             0.0        0               0
# 346  M1400973979             0.0             0.0        0               0
# 347  M1105416433             0.0             0.0        0               0
# 348   M404947798             0.0             0.0        0               0

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349 entries, 0 to 348
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   step            349 non-null    int64
#  1   type            349 non-null    object
#  2   amount          349 non-null    float64
#  3   nameOrig        349 non-null    object
#  4   oldbalanceOrg   349 non-null    float64
#  5   newbalanceOrig  349 non-null    float64
#  6   nameDest        349 non-null    object
#  7   oldbalanceDest  349 non-null    float64
#  8   newbalanceDest  349 non-null    float64
#  9   isFraud         349 non-null    int64
#  10  isFlaggedFraud  349 non-null    int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 30.1+ KB
# None

# %%
print(data.describe())
# Out:
#         step        amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count  349.0  3.490000e+02   3.490000e+02    3.490000e+02    3.490000e+02
# mean     1.0  1.152061e+05   1.338679e+06    1.377742e+06    5.387313e+05
# std      0.0  1.927996e+05   2.476481e+06    2.537942e+06    1.553677e+06
# min      1.0  8.730000e+00   0.000000e+00    0.000000e+00    0.000000e+00
# 25%      1.0  5.392750e+03   0.000000e+00    0.000000e+00    0.000000e+00
# 50%      1.0  4.745886e+04   2.092500e+04    1.248057e+04    8.168258e+04
# 75%      1.0  1.603473e+05   1.080930e+06    1.155863e+06    4.359629e+05
# max      1.0  1.724887e+06   8.623151e+06    8.674805e+06    1.700000e+07
#
#        newbalanceDest     isFraud  isFlaggedFraud
# count    3.490000e+02  349.000000           349.0
# mean     1.161758e+06    0.005731             0.0
# std      3.550613e+06    0.075592             0.0
# min      0.000000e+00    0.000000             0.0
# ...

# %%
print(data.isnull().sum())
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
data = data.dropna()
print(data)
# Out:
#      step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0       1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1       1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2       1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3       1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4       1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
# ..    ...       ...       ...          ...            ...             ...
# 344     1   PAYMENT   5937.72  C1926180325        21779.0        15841.28
# 345     1   PAYMENT   9796.29  C1594039997       274658.0       264861.71
# 346     1   PAYMENT  13449.95  C1170788511        11080.0            0.00
# 347     1   PAYMENT   4749.60   C347091104         8038.0         3288.40
# 348     1   PAYMENT   6460.86  C1110195322        31009.0        24548.14
#
#         nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# ...

# %%
print(data['type'].unique())
# Out:
# ['PAYMENT' 'TRANSFER' 'CASH_OUT' 'DEBIT' 'CASH_IN']

# %%
transposed_data = data.T
print(transposed_data)
# Out:
#                         0            1            2           3    \
# step                      1            1            1           1
# type                PAYMENT      PAYMENT     TRANSFER    CASH_OUT
# amount              9839.64      1864.28        181.0       181.0
# nameOrig        C1231006815  C1666544295  C1305486145  C840083671
# oldbalanceOrg      170136.0      21249.0        181.0       181.0
# newbalanceOrig    160296.36     19384.72          0.0         0.0
# nameDest        M1979787155  M2044282225   C553264065   C38997010
# oldbalanceDest          0.0          0.0          0.0     21182.0
# newbalanceDest          0.0          0.0          0.0         0.0
# isFraud                   0            0            1           1
# isFlaggedFraud            0            0            0           0
#
#                         4           5           6            7            8    \
# step                      1           1           1            1            1
# ...

# %%
merged_data = pd.merge(data, data, on='nameOrig')
print(merged_data)
# Out:
#      step_x    type_x  amount_x     nameOrig  oldbalanceOrg_x  \
# 0         1   PAYMENT   9839.64  C1231006815         170136.0
# 1         1   PAYMENT   1864.28  C1666544295          21249.0
# 2         1  TRANSFER    181.00  C1305486145            181.0
# 3         1  CASH_OUT    181.00   C840083671            181.0
# 4         1   PAYMENT  11668.14  C2048537720          41554.0
# ..      ...       ...       ...          ...              ...
# 344       1   PAYMENT   5937.72  C1926180325          21779.0
# 345       1   PAYMENT   9796.29  C1594039997         274658.0
# 346       1   PAYMENT  13449.95  C1170788511          11080.0
# 347       1   PAYMENT   4749.60   C347091104           8038.0
# 348       1   PAYMENT   6460.86  C1110195322          31009.0
#
#      newbalanceOrig_x   nameDest_x  oldbalanceDest_x  newbalanceDest_x  \
# 0           160296.36  M1979787155               0.0               0.0
# 1            19384.72  M2044282225               0.0               0.0
# ...

# %%
grouped_data = data.groupby('isFraud')
print(grouped_data)

# %%
aggregated_data = grouped_data.agg({'amount': 'mean'})
print(aggregated_data)
# Out:
#                amount
# isFraud
# 0        115869.02683
# 1           181.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(data['amount'], bins=20)
plt.show()

# %%
sns.scatterplot(data['oldbalanceOrg'])
plt.show()

# %%
sns.pairplot(data)
plt.show()

# %%
user_profiles = data.groupby('isFraud').agg({'amount': 'mean'})
print(user_profiles)
# Out:
#                amount
# isFraud
# 0        115869.02683
# 1           181.00000

# %%
data['amount'] = pd.to_datetime(data['amount'])
print(data['amount'])
# Out:
# 0     1970-01-01 00:00:00.000009839
# 1     1970-01-01 00:00:00.000001864
# 2     1970-01-01 00:00:00.000000181
# 3     1970-01-01 00:00:00.000000181
# 4     1970-01-01 00:00:00.000011668
#                    ...
# 344   1970-01-01 00:00:00.000005937
# 345   1970-01-01 00:00:00.000009796
# 346   1970-01-01 00:00:00.000013449
# 347   1970-01-01 00:00:00.000004749
# 348   1970-01-01 00:00:00.000006460
# Name: amount, Length: 349, dtype: datetime64[ns]

# %%
data['nameOrig'] = data['amount'].dt.hour
print(data['nameOrig'])
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 344    0
# 345    0
# 346    0
# 347    0
# 348    0
# Name: nameOrig, Length: 349, dtype: int64
